# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # loading data

# %%
data=pd.read_csv("data.csv")
data.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Id column is not usefull so we can delete it and encode diagnosis values

# %%
data=data.drop(columns=["id"])
data['diagnosis'] = data['diagnosis'].apply(lambda x: 1 if x == 'M' else 0)
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
data.shape
# Out:
# (569, 31)

# %%
data.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# By the above values we can see that area_mean and smoothness mean are not on the same scale so we have to standardize the whole data

# %%
data_std=(x-x.mean())/(x.std())
data_std.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.096100     -2.071512        1.268817   0.983510         1.567087
# 1     1.828212     -0.353322        1.684473   1.907030        -0.826235
# 2     1.578499      0.455786        1.565126   1.557513         0.941382
# 3    -0.768233      0.253509       -0.592166  -0.763792         3.280667
# 4     1.748758     -1.150804        1.775011   1.824624         0.280125
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.280628        2.650542             2.530249       2.215566
# 1         -0.486643       -0.023825             0.547662       0.001391
# 2          1.052000        1.362280             2.035440       0.938859
# 3          3.399917        1.914213             1.450431       2.864862
# 4          0.538866        1.369806             1.427237      -0.009552
#
#    fractal_dimension_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
data['area_radius']=data_std['radius_mean']*data_std['area_mean']
data['se_ar']=data_std['radius_se']+data_std['area_se']

# %%
x=data_std
y=data['diagnosis']

# %%
data_t=pd.concat([y,data_std.iloc[:,0:15]],axis=1)
data_t=pd.melt(data_t,id_vars="diagnosis",var_name="features",value_name='value')
plt.figure(figsize=(40,15))
sns.violinplot(x="features",y="value",hue="diagnosis",data=data_t,split=True,inner="quart")

# %% [markdown]
#  75 percentile of non-cancerious(B) is below 25th percentile of cancerious(M)

# %%
data_t=pd.concat([y,data_std.iloc[:,15:30]],axis=1)
data_t=pd.melt(data_t,id_vars="diagnosis",var_name="features",value_name='value')
plt.figure(figsize=(40,15))
sns.set_context('notebook', font_scale=1.5)
sns.violinplot(x="features",y="value",hue="diagnosis",data=data_t,split=True,inner="quart")

# %%
data_t=pd.concat([y,data_std.iloc[:,30:32]],axis=1)
data_t=pd.melt(data_t,id_vars="diagnosis",var_name="features",value_name='value')
plt.figure(figsize=(40,15))
sns.set_context('notebook', font_scale=1.5)
sns.violinplot(x="features",y="value",hue="diagnosis",data=data_t,split=True,inner="quart")

# %% [markdown]
# from the above plot we can see that radius_worst and perimeter_worst plots are similar it might indicate a correlation between the features, and if two features are correlated,we can drop one

# %%
sns.jointplot(x["radius_worst"], x.loc[:,"perimeter_worst"], kind="regg", color="#ce1414")

# %% [markdown]
# From the plot we can see radius_worst and perimeter_worst are strongly corelated

# %% [markdown]
# # visualizing target variable(diagnosis,in this case)

# %%
sns.countplot(x="diagnosis",data=data)

# %% [markdown]
# correlations between features

# %%
corr_matrix = data_std.corr()
plt.figure(figsize=(30,22))
plt.title("Correlation Between Features")
sns.heatmap(corr_matrix, annot=True, fmt=".2f")

# %%
corr_matrix=["diagnosis",'radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean']
data[corr_matrix].corr()["diagnosis"].sort_values()

# %%
top_corr = ['diagnosis','concave points_mean','perimeter_mean','radius_mean','area_mean','concavity_mean','compactness_mean','texture_mean','area_radius','se_ar']
sns.pairplot(data[top_corr],hue="diagnosis")
plt.show()
# Out:
# C:\Users\sudee\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\sudee\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
data.hist(top_corr,figsize=(10,10))

# %%
plt.figure(figsize=(40,15))
sns.set_context('notebook', font_scale=1.5)
sns.boxplot(x="features",y="value",hue="diagnosis",data=data_t)

# %% [markdown]
# Compactness_mean, concavity_mean and concave points_mean are correlated -> I choose concavity_mean.
#
# radius_se, perimeter_se and area_se are correlated -> I choose area_se.
#
# radius_worst, perimeter_worst and area_worst are correlated -> I choose area_worst.
#
# Compactness_worst, concavity_worst and concave points_worst are correlated -> I choose concavity_worst.
#
# Compactness_se, concavity_se and concave points_se are correlated -> I choose concavity_se.
#
# texture_mean and texture_worst are correlated are correlated -> I choose texture_mean.
#
# area_worst and area_mean are correlated -> I choose area_mean.

# %% [raw]
# we have to drop the other values which are not usefull

# %%
drop_list=['perimeter_mean','radius_mean','compactness_mean','concave points_mean','radius_se','perimeter_se','radius_worst','perimeter_worst','compactness_worst','concave points_worst','compactness_se','concave points_se','texture_worst','area_worst']
a=x.drop(drop_list,axis=1)
a.head()
# Out:
#    texture_mean  area_mean  smoothness_mean  concavity_mean  symmetry_mean  \
# 0     -2.071512   0.983510         1.567087        2.650542       2.215566
# 1     -0.353322   1.907030        -0.826235       -0.023825       0.001391
# 2      0.455786   1.557513         0.941382        1.362280       0.938859
# 3      0.253509  -0.763792         3.280667        1.914213       2.864862
# 4     -1.150804   1.824624         0.280125        1.369806      -0.009552
#
#    fractal_dimension_mean  texture_se   area_se  smoothness_se  concavity_se  \
# 0                2.253764   -0.564768  2.485391      -0.213814      0.723390
# 1               -0.867889   -0.875473  0.741749      -0.604819     -0.440393
# 2               -0.397658   -0.779398  1.180298      -0.296744      0.212889
# 3                4.906602   -0.110312 -0.288125       0.689095      0.818798
# 4               -0.561956   -0.789549  1.189310       1.481763      0.827742
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(a.corr(),annot=True,fmt=".2f")

# %%
#so to check if we have selected correct features lets test it by using random forest algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, recall_score

x_train,x_test,y_train,y_test=train_test_split(a,y,test_size=0.3,random_state=42)
clf=RandomForestClassifier(random_state=43)      
clr=clf.fit(x_train,y_train)
accuracy=accuracy_score(y_test,clf.predict(x_test))
print('Accuracy is: ', accuracy)
recall = recall_score(y_test,clf.predict(x_test))
print('Recall is: ', recall)
f1 = f1_score(y_test,clf.predict(x_test))
print('F1 score is: ', f1)
cm = confusion_matrix(y_test,clf.predict(x_test))
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# Accuracy is:  0.9649122807017544
# Recall is:  0.9365079365079365
# F1 score is:  0.9516129032258064
